# %% [markdown]
# ![Monochrome LinkedIn Banner.png](data:image/png;base64,...)

# %% [markdown]
# ## Author: **MrBriit**
#
# [Click here to follow me on Linkedin](https://www.linkedin.com/in/mrbriit/)
#
# <br>
#
# [Subscrice Youtube and Click on Notification button for more free tutorials and live sessons.](https://www.youtube.com/channel/UC7YlhTyLxk_B1ZcY8CUpCVQ?sub_confirmation=1)

# %% [markdown]
# <br>
#
#
# **IMPORTANT**
#
# This tutorial assumes that you have a basic knowledge of Python.
#
# If not, you can quickly brush up your concepts of Python programming with the [Python Crash Course on Udemy](https://bit.ly/UDEMY-pythoncrashcourse)
#
#
# <br>

# %% [markdown]
# #**Financial Budget Analysis with Python**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/India_budget_2021.csv")
data
# Out:
#                                  Department /Ministry  Fund allotted(in ₹crores)
# 0                             MINISTRY OF AGRICULTURE                  131531.19
# 1                         DEPARTMENT OF ATOMIC ENERGY                   18264.89
# 2                          MINISTRY OF AYURVEDA, YOGA                    2970.30
# 3                MINISTRY OF CHEMICALS AND FERTILISER                   80714.94
# 4                          MINISTRY OF CIVIL AVIATION                    3224.67
# 5                                    MINISTRY OF COAL                     534.88
# 6                   MINISTRY OF COMMERCE AND INDUSTRY                   12768.25
# 7                           MINISTRY OF COMMUNICATION                   75265.22
# 8                        MINISTRY OF CONSUMER AFFAIRS                  256948.40
# 9                       MINISTRY OF CORPORATE AFFAIRS                     712.13
# 10                                MINISTRY OF CULTURE                    2687.99
# ...

# %%
data.shape
# Out:
# (57, 2)

# %%
data.isna().sum()
# Out:
# Department /Ministry         1
# Fund allotted(in ₹crores)    1
# dtype: int64

# %%
data=data.dropna()

# %%
data.isna().sum()
# Out:
# Department /Ministry         0
# Fund allotted(in ₹crores)    0
# dtype: int64

# %%
# data = data.iloc[[0,8,11,14,18,23,41,42,43],:]
# row = {'Department /Ministry': 'OTHERS', 'Fund allotted(in ₹crores)': 592971.0800000001}
# data = data.append(row, ignore_index = True)
# print(data)

# %% [markdown]
# #**Which Ministry Has The Highest Budget Allocation**

# %%
data.plot.bar(x='Department /Ministry', y='Fund allotted(in ₹crores)',figsize=(10,5))

# %%
data=data.iloc[:-1 , :]

# %%
data.plot.bar(x='Department /Ministry', y='Fund allotted(in ₹crores)',figsize=(18,8))
plt.title("Distribution of The Budget For Top 10 Ministries", fontweight='bold')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #**Distribution of The Budget For Top 10 Ministries**

# %%
data = data.sort_values(by='Fund allotted(in ₹crores)',ascending=False)

# %%
new_data=data.head(10)
df = new_data["Fund allotted(in ₹crores)"]
labels = new_data["Department /Ministry"]
plt.figure(figsize=(10,9))
plt.pie(df, labels=labels, autopct='%1.1f%%', startangle=45, pctdistance=0.7, shadow =True)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Distribution of The Budget For Top 10 Ministries", fontweight='bold')
plt.show()

# %%
data.plot.bar(x='Department /Ministry', y='Fund allotted(in ₹crores)',figsize=(18,8)) #you can use 'new_data' to see the only the top 10
plt.title("Distribution of The Budget For Top 10 Ministries", fontweight='bold')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #**Distribution of The Budget For Last 10 Ministries**

# %%
data = data.sort_values(by='Fund allotted(in ₹crores)',ascending=True)
new_data = data.head(10)
new_data
# Out:
#                       Department /Ministry  Fund allotted(in ₹crores)
# 49                       MINISTRY OF STEEL                      39.25
# 34       MINISTRY OF PARLIAMENTARY AFFAIRS                      65.07
# 5                         MINISTRY OF COAL                     534.88
# 9            MINISTRY OF CORPORATE AFFAIRS                     712.13
# 33              MINISTRY OF PANCHAYATI RAJ                     913.43
# 22            MINISTRY OF HEAVY INDUSTRIES                    1017.08
# 37                    MINISTRY OF PLANNING                    1062.77
# 20  MINISTRY OF FOOD PROCESSING INDUSTRIES                    1308.66
# 48                  MINISTRY OF STATISTICS                    1409.13
# 30                       MINISTRY OF MINES                    1466.82

# %%
df = new_data["Fund allotted(in ₹crores)"]
labels = new_data["Department /Ministry"]
plt.figure(figsize=(10,9))
plt.pie(df, labels=labels, autopct='%1.1f%%', startangle=0, pctdistance=0.7, shadow =True)
central_circle = plt.Circle((0, 0), 0.8, color='white') #change the 0.8 to see changes to the circle
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Distribution of The Budget For Last 10 Ministries", fontweight='bold')
plt.show()

# %%
data.plot.bar(x='Department /Ministry', y='Fund allotted(in ₹crores)',figsize=(18,8))
plt.title("Distribution of The Budget For Last 10 Ministries", fontweight='bold')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# **You can plot only the last 10 ministries**

# %%
new_data.plot.bar(x='Department /Ministry', y='Fund allotted(in ₹crores)',figsize=(18,8))
plt.title("Distribution of The Budget For Last 10 Ministries", fontweight='bold')
plt.show
# Out:
# <function matplotlib.pyplot.show>
