# %% [markdown]
# ![Monochrome LinkedIn Banner.png](data:image/png;base64,...)

# %% [markdown]
# ## Author: **MrBriit**
#
# [Click here to follow me on Linkedin](https://www.linkedin.com/in/mrbriit/)
#
# <br>
#
# [Subscrice Youtube and Click on Notification button for more free tutorials and live sessons.](https://www.youtube.com/channel/UC7YlhTyLxk_B1ZcY8CUpCVQ?sub_confirmation=1)

# %% [markdown]
# <br>
#
#
# **IMPORTANT**
#
# This tutorial assumes that you have a basic knowledge of Python.
#
# If not, you can quickly brush up your concepts of Python programming with the [Python Crash Course on Udemy](https://bit.ly/UDEMY-pythoncrashcourse)
#
#
# <br>

# %% [markdown]
# #**Google Search Analysis with Python**

# %% [markdown]
# If you work in a company as a Python data analyst, or data scientist, or business analyst, etc. it is possible for a company to want you analyze the search volume of certain keywords especially if the company wants to enter a particular markert.
#
# For example: let's say your company is an EdTech company(Education Technology company) that offers data science, artificial intelligence, machine learning courses for people to upskill. If they decide to enter into a new region, they want to know is the new region interested in data science, artificial intelligence, machine learning? Do they have companies that will employ the students after learning? Do people know about data science, artificial intelligence, machine learning at all?
#
# All these some feasibility studies that needs to be done before the company will go ahead to invest in the new market. This is one of many scenarios that company will rely on you to provide them with quick insights.
#
# One way you can do this is by using **Google Trend**.
#
# However, as a Python programmer, you can quickly write a Python code that will provide the needed results.
#
#
# Google Trends provides an API known as **pytrends** that can be used to analyze the daily searches on Google.
#
# In this tutorial, we will use the **pytrend** API to draw some insights about certain keyword serches.

# %% [markdown]
# We will use Python to analyze certain keywords.
#
# We will:
#
#
# *   Find the top 10 countries where a particular keyword is being searched the most.
# *   Visualise the top 10 countries using Python Matplotlib library
# * Visualise the trend of the keyword search over the years

# %% [markdown]
# Google doesn’t give much access to the data about daily search queries, but another application of google known as Google Trends can be used for the task of Google search analysis. Google Trends provides an API that can be used to analyze the daily searches on Google. This API is known as pytrends, you can easily install it in your systems by using the pip command; pip install pytrends.

# %% [markdown]
# #**Installation**

# %%
pip install pytrends

# %% [markdown]
# #**Import The Necessary Libraries**

# %%
import pandas as pd
import pytrends
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %% [markdown]
# #**Now Let's Find Countries Where Certain Keywords Are Searched The Most**

# %%
trends.build_payload(kw_list=['analytics']) #add your keyword here
data = trends.interest_by_region()
data = data.sort_values(by="analytics", ascending=False) #sort by the keyword searched volume
data = data.head(20) #get the top 10 or 20 countries
print(data)
# Out:
#                       analytics
# geoName
# Singapore                   100
# China                        91
# St. Helena                   88
# Ireland                      59
# Hong Kong                    53
# Netherlands                  52
# Australia                    48
# New Zealand                  47
# United Kingdom               47
# Canada                       46
# India                        45
# Denmark                      45
# Switzerland                  42
# United States                42
# United Arab Emirates         41
# Lithuania                    40
# Finland                      38
# Kenya                        38
# Israel                       37
# Sweden                       35

# %%
data.reset_index().plot(x="geoName", y="analytics", 
                        figsize=(15,10), kind="bar")
# plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['analytics'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15, 10))
data['analytics'].plot()
plt.style.use('fivethirtyeight')
plt.title("Total Google Searches for keyword: 'Analytics'", fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %% [markdown]
# #**Historical Interest Overtime**

# %%
keywrd_list = ["python programming"]
data = trends.get_historical_interest(keywrd_list, year_start=2020, month_start=1, day_start=1, hour_start=0, year_end=2020, month_end=3, day_end=1, hour_end=0, cat=0, geo='', gprop='', sleep=0)
data = data.sort_values(by="python programming", ascending=False) #sort by the keyword searched volume
data = data.head(30) #get the top 10 or 20 countries
print(data)
# Out:
#                      python programming  isPartial
# date
# 2020-01-09 05:00:00                 100      False
# 2020-02-19 05:00:00                 100      False
# 2020-02-06 06:00:00                 100      False
# 2020-01-07 09:00:00                 100      False
# 2020-02-13 05:00:00                 100      False
# 2020-02-20 05:00:00                 100      False
# 2020-02-04 06:00:00                 100      False
# 2020-02-07 05:00:00                 100      False
# 2020-01-21 05:00:00                 100      False
# 2020-01-23 05:00:00                 100      False
# 2020-01-20 06:00:00                  99      False
# 2020-02-11 05:00:00                  98      False
# 2020-02-07 04:00:00                  98      False
# 2020-01-10 06:00:00                  97      False
# 2020-01-31 05:00:00                  96      False
# 2020-02-12 06:00:00                  96      False
# 2020-01-30 05:00:00                  95      False
# ...

# %%
data.reset_index().plot(x="date", y="python programming", 
                        figsize=(15,6), kind="bar")
# plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['python programming'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15, 6))
data['python programming'].plot()
plt.title("Total Google Searches for keyword: 'Python Programming' overtime", fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
