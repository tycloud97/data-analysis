# %% [markdown]
# ![Monochrome LinkedIn Banner (8).gif](data:image/gif;base64,...)

# %% [markdown]
# ## Author: **MrBriit**
#
# [Click here to follow me on Linkedin](https://www.linkedin.com/in/mrbriit/)
#
# <br>
#
# [Subscrice Youtube and Click on Notification button for more free tutorials and live sessons.](https://www.youtube.com/channel/UC7YlhTyLxk_B1ZcY8CUpCVQ?sub_confirmation=1)

# %% [markdown]
# <br>

# %% [markdown]
# <br>
#
#
# **IMPORTANT**
#
# This project assumes that you have a basic knowledge of Python.
#
# If not, you can quickly brush up your concepts of Python programming with the [Python Crash Course on Udemy](https://bit.ly/UDEMY-pythoncrashcourse)
#
#
# <br>

# %% [markdown]
# #**Healthcare Data Analysis With Python**

# %% [markdown]
# In this tutorial, we will use a healthcare dataset to perform some exploratory data analysis in order to master the concepts of **Python** and **Data Analysis**.

# %% [markdown]
# **About Datset**
#
# This dataset contains around 480,000 records of patients data from the NTR Vaidya Seva scheme of the Government of Andhra Pradesh, India. NTR Vaidya Seva is the flagship healthcare scheme of the government in which lower-middle class and low-income citizens of the state of Andhra Pradesh can obtain free healthcare for many major diseases and ailments.
#
# **Acknowledgements**
#
# Original dataset can be found on the NTR Vaidya Seva's official website. The dataset has been partially anonymized on the official website. I've further anonymized it.
#
#
# **Inspiration**
#
# A useful beginner level real world dataset for exploratory data analysis!
#
# **Ownership**
#
# Dataset owned by the Government of Andhra Pradesh but released freely on official website.

# %% [markdown]
# <br>
#
#
#
# ---
#
#
#
# ---
#
#
#
# <br>

# %% [markdown]
# **Import the necessary libraries**

# %%
# import requisite libraries 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("/content/health.csv")
df.head()
# Out:
#         AGE     SEX  ... Mortality Y / N MORTALITY_DATE SRC_REGISTRATION
# 0    1   56  Female  ...              NO            NaN                D
# 1    2   37    Male  ...              NO            NaN                D
# 2    3   50    Male  ...              NO            NaN                D
# 3    4   45    Male  ...              NO            NaN                D
# 4    5   54    Male  ...              NO            NaN                D
#
# [5 rows x 24 columns]

# %% [markdown]
# ###**Summary Of Dataset**

# %%
# print summary statistics
df.describe().T
# Out:
#                  count           mean  ...        75%       max
#               342642.0  171321.500000  ...  256981.75  342642.0
# AGE           342642.0      44.491358  ...      58.00     107.0
# PREAUTH_AMT   342641.0   31230.033531  ...   35000.00  520000.0
# CLAIM_AMOUNT  342641.0   28147.961400  ...   30870.00  520000.0
#
# [4 rows x 8 columns]

# %% [markdown]
# We can see from the above summary matrix that the average age of a patience is **44** with the oldest being **107**.
#
# We also notice that the minimum **pre-authorised amount** is around **5** and maximum is **520000** with and average of **31408**.
#
# Also **claim amount** has an average of **28202**, minimu of **2** and maximum of **520000**.

# %% [markdown]
# <br>
#
# ###**Distribution Of Gender**

# %%
df['SEX'].value_counts()
# Out:
# Male             186999
# Female           124952
# Male(Child)       19130
# Female(Child)     11560
# FEMALE                1
# Name: SEX, dtype: int64

# %% [markdown]
# As we can see there are duplicate values ​​in this column. Male and MALE are not two different sexes. We can substitute the column names to resolve this issue. I will also rename Male (Child) -> Boy and Female (Child) -> Girl for convenience.

# %%
mappings = {'MALE' : 'Male', 'FEMALE' : 'Female', 'Male(Child)' : 'Boy', 'Female(Child)' : 'Girl'}
# replace values using the defined mappings
df['SEX'] = df['SEX'].replace(mappings)
df['SEX'].value_counts()
# Out:
# Male      186999
# Female    124953
# Boy        19130
# Girl       11560
# Name: SEX, dtype: int64

# %%
# plot the value counts of sex 
df['SEX'].value_counts().plot.bar()

# %% [markdown]
# We notice that there are more males patiences in our dataset.

# %% [markdown]
# ###**Age Range And Distribution**

# %%
sns.boxplot(df['AGE'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# As we can see, the age ranges from **0** to **100** with some outliers going beyond 100.

# %% [markdown]
# ###**For Each District Find Out The Most Common Surgery Type That Is Being Performed.**

# %%
for i in df['DISTRICT_NAME'].unique():
    print("District: {}\n Disease and Count: {}\n '============'\n".format(i,df[df['DISTRICT_NAME']==i]['SURGERY'].value_counts().head(1)))
# Out:
# District: Srikakulam
#  Disease and Count: Maintenance Hemodialysis For Crf    3236
# Name: SURGERY, dtype: int64
#  '============'
#
# District: Kurnool
#  Disease and Count: Surgical Correction Of Longbone Fracture    2044
# Name: SURGERY, dtype: int64
#  '============'
#
# District: Vizianagaram
#  Disease and Count: Surgical Correction Of Longbone Fracture    1850
# Name: SURGERY, dtype: int64
#  '============'
#
# District: Guntur
#  Disease and Count: Surgical Correction Of Longbone Fracture    3510
# Name: SURGERY, dtype: int64
#  '============'
#
# District: Vishakhapatnam
#  Disease and Count: Maintenance Hemodialysis For Crf    4157
# Name: SURGERY, dtype: int64
#  '============'
#
# District: West Godavari
#  Disease and Count: Maintenance Hemodialysis For Crf    4253
# Name: SURGERY, dtype: int64
#  '============'
#
# District: Krishna
#  Disease and Count: Maintenance Hemodialysis For Crf    4802
# Name: SURGERY, dtype: int64
#  '============'
#
# District: East Godavari
#  Disease and Count: Maintenance Hemodialysis For Crf    5071
# Name: SURGERY, dtype: int64
#  '============'
#
# District: Prakasam
#  Disease and Count: Maintenance Hemodialysis For Crf    4974
# Name: SURGERY, dtype: int64
#  '============'
#
# District: Nellore
#  Disease and Count: Maintenance Hemodialysis For Crf    7971
# Name: SURGERY, dtype: int64
#  '============'
#
# District: YSR Kadapa
#  Disease and Count: Surgical Correction Of Longbone Fracture    3017
# Name: SURGERY, dtype: int64
#  '============'
#
# District: Chittoor
#  Disease and Count: Maintenance Hemodialysis For Crf    3828
# Name: SURGERY, dtype: int64
#  '============'
#
# District: Anantapur
#  Disease and Count: Surgical Correction Of Longbone Fracture    3335
# Name: SURGERY, dtype: int64
#  '============'
#
# District: nan
#  Disease and Count: Series([], Name: SURGERY, dtype: int64)
#  '============'

# %% [markdown]
# <br>
#
# Our analysis shows that **Nellore** performs Maintenance Hemodialysis For Crf which has the highest surgery count.
#
# We can also notice that there are two surgeries involved in all districts, e.i. **Hemodialysis** and **Longbone Fracture**.

# %% [markdown]
# <br>
#
# ###**For Each District Find Out The Average Claim Amount.**

# %%
for i in df['DISTRICT_NAME'].unique():
    print("District: {}\n Average Claim Amount: ₹{}\n '============'\n".format(i,df[df['DISTRICT_NAME']==i]['CLAIM_AMOUNT'].mean()))
# Out:
# District: Srikakulam
#  Average Claim Amount: ₹25974.16914298019
#  '============'
#
# District: Kurnool
#  Average Claim Amount: ₹29044.40670480357
#  '============'
#
# District: Vizianagaram
#  Average Claim Amount: ₹25451.533863222387
#  '============'
#
# District: Guntur
#  Average Claim Amount: ₹31862.141720317206
#  '============'
#
# District: Vishakhapatnam
#  Average Claim Amount: ₹26131.672162948595
#  '============'
#
# District: West Godavari
#  Average Claim Amount: ₹28716.43737338456
#  '============'
#
# District: Krishna
#  Average Claim Amount: ₹31671.672472815142
#  '============'
#
# District: East Godavari
#  Average Claim Amount: ₹26670.853882193773
#  '============'
#
# District: Prakasam
#  Average Claim Amount: ₹29145.03509204471
#  '============'
#
# District: Nellore
#  Average Claim Amount: ₹26531.491073038775
#  '============'
#
# District: YSR Kadapa
#  Average Claim Amount: ₹28527.394680901318
#  '============'
#
# District: Chittoor
#  Average Claim Amount: ₹25899.314389970736
#  '============'
#
# District: Anantapur
#  Average Claim Amount: ₹28147.75884389583
#  '============'
#
# District: nan
#  Average Claim Amount: ₹nan
#  '============'

# %% [markdown]
# <br>
#
# ###**Group Summary Statistics**

# %%
df.groupby('CATEGORY_NAME').mean().sort_values(by='PREAUTH_AMT', ascending=False)
# Out:
#                                                     ...   CLAIM_AMOUNT
# CATEGORY_NAME                                       ...
# COCHLEAR IMPLANT SURGERY              46208.442857  ...  516285.714286
# CARDIAC AND CARDIOTHORACIC SURGERY   164843.016032  ...   83041.835383
# CRITICAL CARE                        148683.326284  ...   49843.704532
# SURGICAL GASTRO ENTEROLOGY           173289.463964  ...   57865.291667
# PLASTIC SURGERY                      157679.400286  ...   36837.024303
# NEUROSURGERY                         176425.678263  ...   49675.954949
# SURGICAL ONCOLOGY                    184695.473470  ...   41857.487006
# GASTROENTEROLOGY                     117994.747698  ...   23126.513505
# PEDIATRIC SURGERIES                  173736.501921  ...   31838.257042
# RADIATION ONCOLOGY                   182997.976809  ...   32167.150669
# CARDIOLOGY                           149188.109780  ...   26405.507245
# PULMONOLOGY                          139991.505704  ...   25239.389228
# POLY TRAUMA                          190879.375217  ...   27995.561632
# GENERAL SURGERY                      171533.014990  ...   27846.790147
# GENERAL MEDICINE                      84541.947326  ...   20910.051053
# GENITO URINARY SURGERIES             204391.125360  ...   28898.270627
# PEDIATRICS                           139476.897903  ...   24551.287775
# RHEUMATOLOGY                         119336.063830  ...   20887.680851
# INFECTIOUS DISEASES                  223879.250000  ...   23427.500000
# GYNAECOLOGY AND OBSTETRICS  SURGERY  148888.000676  ...   22749.525533
# DERMATOLOGY                          124004.880000  ...   21913.733333
# ORTHOPEDIC  SURGERY AND PROCEDURES   156027.308864  ...   22919.051377
# NEUROLOGY                            130040.500999  ...   19666.468682
# ENDOCRINOLOGY                        136023.335632  ...   15005.620690
# OPHTHALMOLOGY  SURGERY               209035.314759  ...   16109.743513
# ENT  SURGERY                         182036.925559  ...   14905.715430
# NEPHROLOGY                           143459.466677  ...   13681.514021
# MEDICAL ONCOLOGY                     203715.739703  ...    6889.033205
# PROSTHESES                           125094.500000  ...    1200.000000
#
# [29 rows x 4 columns]

# %% [markdown]
# Cochlear Implant Surgery seems to be the costliest surgery, costing ₹520000 on average. Prostheses costs ₹1200, the cheapest. The youngest age group also happens to be for Cochlear Implant Surgery: 1.58 years, while Neurology has an average patient age of ~56.

# %% [markdown]
# ##**Summary Statistics For Each Hospital**

# %%
df.groupby('HOSP_NAME').mean().sort_values(by='PREAUTH_AMT', ascending=False)
# Out:
#                                                                    ...   CLAIM_AMOUNT
# HOSP_NAME                                                          ...
# Maa Hospitals  Pvt. Ltd. Unit Of Vasavi Ent Ins...   21998.200000  ...  520000.000000
# Ent Nursing Home                                    145554.376344  ...  232398.494624
# Quality Care India Ltd Care Hospitals- Nampally     155487.701863  ...  102985.229814
# Ravindranath Ge Medical Associates Pvt Ltd. Glo...  155569.859784  ...   99170.801233
# Apollo Hospitals Enterprises Ltd Jubilee Hills      153850.742775  ...   94593.624277
# ...                                                           ...  ...            ...
# DR AKBAR EYE HOSPITAL PHACO AND LASER CENTER        237936.109589  ...   10997.986301
# SREE NETHRA ENT AND EYE CARE HOSPITAL               264881.411765  ...   10787.568627
# RAGHAVENDRA HOSPITAL                                316097.690000  ...   10581.600000
# VIJAYA HOSPITALS                                    306145.857143  ...    9714.285714
# SPARK HOSPITALS                                      12862.000000  ...   10000.000000
#
# [449 rows x 4 columns]

# %% [markdown]
# <br>
#
# **Maa Hospitals Pvt. Ltd.** cost the highest with
# **pre-Authorised amount** of **520000**.

# %% [markdown]
# ## **Most common surgery and count per age group**

# %%
# Most common surgery and count per age group
for i in sorted(df['AGE'].unique()):
    print("Age Group: {}\nMost Common Surgery and Count: {}\n'============'\n".format(i,df[df['AGE']==i]['CATEGORY_NAME'].value_counts().head(1)))
# Out:
# Age Group: 0
# Most Common Surgery and Count: PEDIATRICS    12088
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 1
# Most Common Surgery and Count: PEDIATRICS    1226
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 2
# Most Common Surgery and Count: PEDIATRICS    668
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 3
# Most Common Surgery and Count: PEDIATRICS    506
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 4
# Most Common Surgery and Count: PEDIATRICS    551
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 5
# Most Common Surgery and Count: PEDIATRICS    247
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 6
# Most Common Surgery and Count: PEDIATRICS    245
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 7
# Most Common Surgery and Count: POLY TRAUMA    216
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 8
# Most Common Surgery and Count: PEDIATRICS    264
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 9
# Most Common Surgery and Count: POLY TRAUMA    265
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 10
# Most Common Surgery and Count: POLY TRAUMA    254
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 11
# Most Common Surgery and Count: PEDIATRICS    243
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 12
# Most Common Surgery and Count: POLY TRAUMA    347
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 13
# Most Common Surgery and Count: POLY TRAUMA    381
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 14
# Most Common Surgery and Count: POLY TRAUMA    354
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 15
# Most Common Surgery and Count: POLY TRAUMA    344
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 16
# Most Common Surgery and Count: POLY TRAUMA    421
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 17
# Most Common Surgery and Count: POLY TRAUMA    448
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 18
# Most Common Surgery and Count: POLY TRAUMA    424
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 19
# Most Common Surgery and Count: POLY TRAUMA    456
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 20
# Most Common Surgery and Count: POLY TRAUMA    535
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 21
# Most Common Surgery and Count: POLY TRAUMA    507
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 22
# Most Common Surgery and Count: POLY TRAUMA    565
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 23
# Most Common Surgery and Count: POLY TRAUMA    528
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 24
# Most Common Surgery and Count: POLY TRAUMA    572
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 25
# Most Common Surgery and Count: POLY TRAUMA    657
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 26
# Most Common Surgery and Count: NEPHROLOGY    584
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 27
# Most Common Surgery and Count: GENITO URINARY SURGERIES    582
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 28
# Most Common Surgery and Count: POLY TRAUMA    669
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 29
# Most Common Surgery and Count: POLY TRAUMA    621
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 30
# Most Common Surgery and Count: NEPHROLOGY    829
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 31
# Most Common Surgery and Count: NEPHROLOGY    773
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 32
# Most Common Surgery and Count: NEPHROLOGY    790
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 33
# Most Common Surgery and Count: NEPHROLOGY    812
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 34
# Most Common Surgery and Count: NEPHROLOGY    912
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 35
# Most Common Surgery and Count: NEPHROLOGY    1119
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 36
# Most Common Surgery and Count: NEPHROLOGY    1029
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 37
# Most Common Surgery and Count: NEPHROLOGY    952
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 38
# Most Common Surgery and Count: NEPHROLOGY    1146
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 39
# Most Common Surgery and Count: NEPHROLOGY    1121
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 40
# Most Common Surgery and Count: MEDICAL ONCOLOGY    1676
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 41
# Most Common Surgery and Count: NEPHROLOGY    1317
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 42
# Most Common Surgery and Count: NEPHROLOGY    1310
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 43
# Most Common Surgery and Count: NEPHROLOGY    1500
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 44
# Most Common Surgery and Count: NEPHROLOGY    1538
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 45
# Most Common Surgery and Count: NEPHROLOGY    2177
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 46
# Most Common Surgery and Count: NEPHROLOGY    1820
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 47
# Most Common Surgery and Count: NEPHROLOGY    1425
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 48
# Most Common Surgery and Count: NEPHROLOGY    1810
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 49
# Most Common Surgery and Count: NEPHROLOGY    1486
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 50
# Most Common Surgery and Count: NEPHROLOGY    2363
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 51
# Most Common Surgery and Count: NEPHROLOGY    1638
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 52
# Most Common Surgery and Count: NEPHROLOGY    1545
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 53
# Most Common Surgery and Count: NEPHROLOGY    1660
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 54
# Most Common Surgery and Count: NEPHROLOGY    1393
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 55
# Most Common Surgery and Count: NEPHROLOGY    2192
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 56
# Most Common Surgery and Count: NEPHROLOGY    1790
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 57
# Most Common Surgery and Count: NEPHROLOGY    1294
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 58
# Most Common Surgery and Count: NEPHROLOGY    1417
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 59
# Most Common Surgery and Count: NEPHROLOGY    1080
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 60
# Most Common Surgery and Count: MEDICAL ONCOLOGY    1713
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 61
# Most Common Surgery and Count: NEPHROLOGY    1072
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 62
# Most Common Surgery and Count: NEPHROLOGY    862
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 63
# Most Common Surgery and Count: NEPHROLOGY    906
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 64
# Most Common Surgery and Count: NEPHROLOGY    651
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 65
# Most Common Surgery and Count: MEDICAL ONCOLOGY    1537
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 66
# Most Common Surgery and Count: POLY TRAUMA    908
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 67
# Most Common Surgery and Count: CARDIAC AND CARDIOTHORACIC SURGERY    544
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 68
# Most Common Surgery and Count: NEPHROLOGY    671
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 69
# Most Common Surgery and Count: POLY TRAUMA    543
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 70
# Most Common Surgery and Count: POLY TRAUMA    1428
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 71
# Most Common Surgery and Count: POLY TRAUMA    867
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 72
# Most Common Surgery and Count: POLY TRAUMA    428
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 73
# Most Common Surgery and Count: POLY TRAUMA    417
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 74
# Most Common Surgery and Count: POLY TRAUMA    392
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 75
# Most Common Surgery and Count: POLY TRAUMA    865
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 76
# Most Common Surgery and Count: POLY TRAUMA    556
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 77
# Most Common Surgery and Count: POLY TRAUMA    236
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 78
# Most Common Surgery and Count: POLY TRAUMA    233
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 79
# Most Common Surgery and Count: POLY TRAUMA    211
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 80
# Most Common Surgery and Count: POLY TRAUMA    450
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 81
# Most Common Surgery and Count: POLY TRAUMA    242
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 82
# Most Common Surgery and Count: POLY TRAUMA    88
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 83
# Most Common Surgery and Count: POLY TRAUMA    88
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 84
# Most Common Surgery and Count: POLY TRAUMA    81
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 85
# Most Common Surgery and Count: POLY TRAUMA    167
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 86
# Most Common Surgery and Count: POLY TRAUMA    107
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 87
# Most Common Surgery and Count: POLY TRAUMA    42
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 88
# Most Common Surgery and Count: POLY TRAUMA    25
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 89
# Most Common Surgery and Count: POLY TRAUMA    23
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 90
# Most Common Surgery and Count: POLY TRAUMA    50
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 91
# Most Common Surgery and Count: POLY TRAUMA    21
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 92
# Most Common Surgery and Count: POLY TRAUMA    9
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 93
# Most Common Surgery and Count: POLY TRAUMA    4
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 94
# Most Common Surgery and Count: POLY TRAUMA    6
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 95
# Most Common Surgery and Count: POLY TRAUMA    6
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 96
# Most Common Surgery and Count: POLY TRAUMA    3
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 100
# Most Common Surgery and Count: POLY TRAUMA    1
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 101
# Most Common Surgery and Count: POLY TRAUMA    1
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 107
# Most Common Surgery and Count: POLY TRAUMA    1
# Name: CATEGORY_NAME, dtype: int64
# '============'

# %%
df['DISTRICT_NAME'].value_counts()
# Out:
# East Godavari     39913
# Guntur            36191
# Krishna           29796
# West Godavari     28630
# Nellore           27725
# Chittoor          27679
# Vishakhapatnam    26806
# Prakasam          24336
# Kurnool           23774
# YSR Kadapa        21169
# Anantapur         19929
# Srikakulam        18576
# Vizianagaram      18117
# Name: DISTRICT_NAME, dtype: int64
# East Godavari     39913
# Guntur            36191
# Krishna           29796
# West Godavari     28630
# Nellore           27725
# Chittoor          27679
# Vishakhapatnam    26806
# Prakasam          24336
# Kurnool           23774
# YSR Kadapa        21169
# Anantapur         19929
# Srikakulam        18576
# Vizianagaram      18117
# Name: DISTRICT_NAME, dtype: int64

# %% [markdown]
# <br>
#
# ##**Time Series Analysis**

# %%
from datetime import datetime

df['SURGERY_DATE']=pd.to_datetime(df['SURGERY_DATE'])

# %%
df.set_index('SURGERY_DATE', inplace=True)

# %%
df.head()
# Out:
#                    AGE     SEX  ... Mortality Y / N MORTALITY_DATE SRC_REGISTRATION
# SURGERY_DATE                    ...
# 2013-06-08      1   56  Female  ...              NO            NaN                D
# 2013-08-08      2   37    Male  ...              NO            NaN                D
# 2013-08-15      3   50    Male  ...              NO            NaN                D
# 2013-08-24      4   45    Male  ...              NO            NaN                D
# 2013-08-31      5   54    Male  ...              NO            NaN                D
#
# [5 rows x 23 columns]

# %% [markdown]
# <br>
#
# ####**Pre-Authorised Amount Over-time**

# %% [markdown]
# We will use the average of the last 12 data points to check the trend. We will use a technique called *rolling average*.
#
# A simple [***rolling average***](https://www.portent.com/blog/analytics/rolling-averages-math-moron.htm) (also called a moving average) is the unweighted mean of the last n values.

# %%
preauthoried = df[['PREAUTH_AMT']]
preauthoried.rolling(12).mean().plot(figsize=(20,10), linewidth=2, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %% [markdown]
# The highest pre-authorised amounts are seen in the month of **July 2015** and early **2016**.
#
# We can also notice that there has been a lot of clustered pre-authorised amounts between **25000** and **100000** in **January 2016** and **July 2017**.

# %% [markdown]
# <br>
#
# ####**Claim Amount Over-time**

# %%
claim = df[['CLAIM_AMOUNT']]
claim.rolling(12).mean().plot(figsize=(20,10), linewidth=2, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %% [markdown]
# We have a similar account as the *Pre-Authorised Amount Over-time*

# %% [markdown]
# <br>
#
# ####**Patiences' Age Overtime**

# %%
age = df[['AGE']]
age.rolling(12).mean().plot(figsize=(20,10), linewidth=2, fontsize=20,color='red')
plt.xlabel('Year', fontsize=20);

# %% [markdown]
# Around **2014**, there were few old age patiences as compare to between **January, 2016** and **July 2017** where number of both young and old patiences increased significantly.
